# %%
import os
current_script_dir = os.path.dirname(os.path.abspath(_))
project_root = os.path.abspath(os.path.join(current_script_dir, os.pardir))
#model_load_directory = os.path.join(project_root, "models")
audio_processor_directory = os.path.join(project_root, "audio_processor")

print(current_script_dir)
print(project_root)
#print(model_load_directory)
print(audio_processor_directory)

# %%
current_script_dir = os.path.dirname(os.path.abspath("data_labeller"))
project_root = os.path.abspath(os.path.join(current_script_dir, os.pardir))
audio_processor_directory = os.path.join(project_root, "audio_processor")

print(current_script_dir)
print(project_root)
print(audio_processor_directory)

# %%
project_root = os.path.abspath(os.path.join(current_script_dir, os.pardir, os.pardir))
print(project_root)

# %%
import os
current_script_dir = os.path.dirname(os.path.abspath("data_labeller"))
project_root = os.path.abspath(os.path.join(current_script_dir,"DrumScript", os.pardir,os.pardir))
audio_processor_directory = os.path.join(project_root, "audio_processor")
print(current_script_dir)
print(project_root)
print(audio_processor_directory)

# %%
"""import os
import sys

abspath = os.path.abspath(__file__)
dname = os.path.dirname(abspath)
os.chdir(dname)


# -----

os.chdir(sys.path[0])"""

"""import os
import sys

#abspath = os.path.abspath(__file__)
abspath = os.path.abspath("")
dname = os.path.dirname(abspath)
os.chdir(dname)"""


# -----

"""#os.chdir(sys.path(""))

print(abspath)
print(dname)"""
